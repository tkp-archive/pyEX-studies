# %%
# %matplotlib inline
import pyEXstudies as ps
import seaborn as sns
sns.set()

# %%
ps.bollinger('aapl').plot()

# %%
sns.heatmap(ps.peerCorrelation('aapl'))

# %%
ps.ema('aapl').plot()

# %%
ps.ema('aapl', '5y', periods=[30, 200]).plot()

# %%
ps.sar('aapl').plot()

# %%
ps.rsi('aapl').plot()
