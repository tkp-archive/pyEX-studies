# %%
# %matplotlib inline
import pyEXstudies as ps
import seaborn as sns
sns.set()

# %%
ps.bollinger('aapl').plot(figsize=(12,5))

# %%
sns.heatmap(ps.peerCorrelation('aapl'))

# %%
ps.ema('aapl').plot(figsize=(12,5))

# %%
ps.ema('aapl', '5y', periods=[30, 200]).plot(figsize=(12,5))

# %%
ps.sar('aapl').plot(figsize=(12,5))

# %%
ps.rsi('aapl').plot(figsize=(12,5))
