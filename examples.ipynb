# %%
# %matplotlib inline
import pyEX as p
import seaborn as sns
sns.set()

# %%
c = p.Client(version='sandbox')
c.bollinger('aapl').plot(figsize=(12,5))

# %%
sns.heatmap(c.peerCorrelation('gs'))

# %%
c.ema('aapl').plot(figsize=(12,5))

# %%
c.ema('aapl', '5y', periods=[30, 200]).plot(figsize=(12,5))

# %%
c.sar('aapl').plot(figsize=(12,5))

# %%
c.rsi('aapl').plot(figsize=(12,5), secondary_y="rsi")
